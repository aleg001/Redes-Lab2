# %%
import matplotlib.pyplot as plt
import seaborn as sns

similitudes = []

with open('similitudes.txt', 'r') as file:
    for line in file:
        similitudes.append(float(line.strip()))

plt.figure(figsize=(10, 6))
sns.histplot(similitudes, bins=20, kde=True)
plt.title("Histograma de Similitudes")
plt.xlabel("Similitud")
plt.ylabel("Frecuencia")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(similitudes, shade=True)
plt.title("Gráfico de Densidad de Similitudes")
plt.xlabel("Similitud")
plt.ylabel("Densidad")
plt.show()
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_6892\1933101890.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(similitudes, shade=True)

# %%
import pandas as pd
import numpy as np

similitudes = []

with open('similitudes.txt', 'r') as file:
    for line in file:
        similitudes.append(float(line.strip()))

df = pd.DataFrame(similitudes, columns=['Similitud'])

# Calcular estadísticas descriptivas
descripcion = df.describe()

# Calcular la mediana
mediana = df.median()

# Calcular la moda
moda = df.mode()

# Calcular la desviación estándar
std_dev = df.std()

print("Estadísticas Descriptivas:")
print(descripcion)
print("\nMediana:")
print(mediana)
print("\nModa:")
print(moda)
print("\nDesviación Estándar:")
print(std_dev)
# Out:
# Estadísticas Descriptivas:
#           Similitud
# count  10120.000000
# mean      87.489723
# std        8.801480
# min       29.000000
# 25%       84.000000
# 50%       90.000000
# 75%       93.000000
# max      100.000000
#
# Mediana:
# Similitud    90.0
# dtype: float64
#
# Moda:
#    Similitud
# 0       86.0
#
# Desviación Estándar:
# Similitud    8.80148
# dtype: float64
